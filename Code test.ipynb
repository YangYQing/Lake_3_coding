# %%
# individual case output test
import os
import numpy as np
from lake_functions import *
from lake_cases import *
import datetime as dtt
import matplotlib.pyplot as plt

# PARAMETERS
#Time
nyears=2
tyear=np.tile(np.arange(1,366,1),[1,nyears]) # DOY
tyear=tyear[0];
t=np.arange(1,365*nyears+1,1) # Time in days from the first day

# Meteorological data:
meteodata_NASA =np.genfromtxt("Meteo_data_NASA.txt", usecols=tuple(np.arange(3,9,1)),skip_header=1,dtype=float)
meteodata_NASA=np.tile(meteodata_NASA,[nyears,1]) 
Ta=meteodata_NASA[:,4]  # [°C]
RH=meteodata_NASA[:,2]  # [#]
Wsp=meteodata_NASA[:,5]  # [m/s]
R=meteodata_NASA[:,1]*10**6/(24*3600)  # [W/m^2]
P=meteodata_NASA[:,3]*1000  # [Pa]

# Atmospheric variables:
rho_air=1.2  # [kg/m^3], air density
CD=0.001  # [-], drag coefficient

#Basin:
hmax=8; # [m], lake depth

# Heat fluxes:
Twinter=4
Adiff=0.066  # [-], albedo of diffuse shortwave radiation
Adir=0.1  # [-], albedo of direct shortwave radiation (approximate value for 50°N)
C=0.5  # Cloudiness
Fdir=(1-C)/((1-C)+0.5*C) 
Fdiff=0.5*C/((1-C)+0.5*C) 
Hsw0=-R*(Fdir*(1-Adir)+Fdiff*(1-Adiff))  # [W/m^2], shortwave radiation (<0) passing through the lake surface

# Gravity
g=9.81 # [m.s^(-2)]

# Water and particles properties:
Dp=1.6*10**(-6)  # [m]
rho_p=2650 # [kg/m^3]
nu=1E-6  # [m^2/s]
Vs=g*(rho_p-1000)/1000*Dp**2/(18*nu)  # [m/s], settling velocity
f_fft=10  # [%], solids content in the FFT
C_FFT=f_fft*10**4  # [g/m^3], solids concentration in the FFT

# THERMOCLINE

iceoff=(dtt.datetime(2015,4,26)-dtt.datetime(2015,1,1)).days  # iceoff DOY (based on observations)
iceon=max(t)   # initial value for the iceon DOY, it will be calculated by the simulation
h_epi=np.zeros(np.shape(t)); h_epi[0]=hmax 

# INITIALIZATION

 # Temperature:
T_epi=np.zeros(np.shape(t)); T_epi[0]=Twinter   # [°C]
T_hypo=np.zeros(np.shape(t)); T_hypo[0]=Twinter   # [°C]

 # Solids concentration:
Css_epi=np.zeros(np.shape(t)); Css_epi[0]=100   # [mg/L]
Css_hypo=np.zeros(np.shape(t)); Css_hypo[0]=100   # [mg/L]

# %%
#case 1
import numpy as np
import sys
from lake_functions import alphaT,rho_TCss, seasonal_therm
from statistics import mean

def case1(VAR_LAKE,Twinter=4,hmax=8):
    """
    Winter case: ice-covered lake, no heat fluxes = constant temperatures 
    and concentrations. 
     
    INPUTS:
        VAR_LAKE: dictionary containing
            T_epi, T_hypo: epilimnion and hypolimnion temperatures [°C]
            Css_epi, Css_hypo: epilimnion and hypolimnion solids concentrations [mg/L]
            h_epi: thermocline depth [m]
        Twinter: temperature of maximum density [°C]
        hmax: lake depth [m]
        
    OUTPUTS:
        VAR_LAKE: dictionary containing the same variables than VAR_LAKE but at the next time step
    """

    # -------- CODE --------
    # Temperature
    T_epi1 = Twinter
    T_hypo1 = Twinter
    # solid concentrations
    Css_epi1 = 100
    Css_hypo1 = 100

    h_epi1 = hmax
    
    VAR_LAKE={"T_epi":T_epi1,"T_hypo":T_hypo1,"Css_epi":Css_epi1,"Css_hypo":Css_hypo1,"h_epi":h_epi1}

    return VAR_LAKE

# %%
def case2(VAR_LAKE,Hsurf,Hsw0,tyear,iceon,Vs,C_FFT,hmax=8,g=9.81,Cpw=4200,Twinter=4,A0=7.8*10**6):
    """
    Fall turnover case: one box with heat fluxes.
     
    INPUTS:
        VAR_LAKE: dictionary containing
            T_epi, T_hypo: epilimnion and hypolimnion temperatures [°C]
            Css_epi, Css_hypo: epilimnion and hypolimnion solids concentrations [mg/L]
            h_epi: thermocline depth [m]
        Hsurf: surface heat flux [W/m^2]
        Hsw0: surface radiation flux [W/m^2]
        tyear: time as DOY
        iceon: iceon date as DOY
        Vs: settling velocity [m/s]
        C_FFT: solids concentration in the FFT [g/m^3]
        hmax: lake depth [m]
        g: gravitational acceleration [m/s^2]
        Cpw: heat capacity of water [J.kg^(-1).K^(-1)]
        Twinter: temperature of maximum density [°C]
        A0: lake surface area [m^2]
        
        
    OUTPUTS:
        VAR_LAKE: dictionary containing the same variables than VAR_LAKE but at the next time step
        iceon: iceon date as DOY (modified only if ice formation after initial iceon date)
    """
    # ----Initial setup----
    h_epi2 = hmax  # Thermocline depth
    T2 = VAR_LAKE["T_epi"]  # Temperature, constant
    T_hypo = VAR_LAKE["T_hypo"] # Hypolimnion temperature for stable condition
    Css2 = VAR_LAKE["Css_epi"] # Initial solid concentration constants
    
    # ----Special process in fall----
    # --Redistribution--
    alpha2 = alphaT(T2)
    kd = 0.325 + 66 * Css2 / 1000  # mg/L
    B = alpha2*g*(Hsurf + Hsw0*(1-np.exp((0.325+66*Css2)*hmax))) / (rho_w0 * Cpw)

    # --stability and concentration calculate--
    if B > 0: # unstable, fully mixed, new epi. depth is constant
        hepi_new = hmax
# ABOUT this part, I'm not sure if I understood the comments and process correctly. I just wrote this as a temporary version to see if they work.
        # Hsw0, consider different layer # ALSO, A BIT CONFUSED WITH THIS COMMENT
        Qnet2 = -(Hsurf + Hsw0)*A0
        dT2 = (Qnet2/(m_w0*Cpw))/24*60*60
        Tepi_new = T2 + dT2
        Thypo_new = Tepi_new
        
        if Tepi_new <= 4: #additional safety check
            if t[k] > 200:
                iceon = t[k]
            else:
                print("Warning, Ice in Summer!")
                Tepi_new = Twinter
                Thypo_new = Twinter
        else: # no ice
            # calculate velocities
            rho_30 = rho_TCss(T2, 30)
            N_fft2 = g*(rho_30-rho_w0)/(0.5*rho_fft0) 
            Vr = (1+2*0.2)*B/(N_fft2*hmax)
            # water mass
            m_w0 = rho_w0*A0*hmax 
            # new concentration
            C_sed = -Css2*Vs*A0*24*60*60/A0*hmax
            C_red = C_FFT*Vr*A0*24*60*60/A0*hmax
            Cssnew2 = Css2 + C_sed + C_red
            Csse_new = Cssnew2
            Cssh_new = Cssnew2
            # safety check
            if Cssnew2 < 0:
                print("Warning, Solid Concentration Error!")
            elif Vr < 0:
                print("Warning, Resettling Velocity Error!")
    else: # stable
        T_avg = T2 + Hsurf *24*3600/(Cpw*rho_w0*h_epi)
        T_surf = 2*T_avg - T_hypo
        # density of 2 layers
        rho1 = rho_TCss(T_surf,Css)
        rho2 = rho_TCss(T_hypo,Css)
        rho_avg = (rho1+rho2)/2
        # N^2
        N2 = g*(rho1 - rho2)/ rho_avg / h_epi
        # new depth of thermocline
        hepi_new = seasonal_therm(h_epi,3600*24,B,N2)
        # ---Identify: stratified---
        if hepi_new > (hmax - 0.1): # stratified ignored
            hepi_new = hmax
            Tepi_new = T_avg
            Thypo_new = T_avg
        else:
            T_therm = T_surf - (hepi_new/hmax)*(T_surf - T_hypo)
            Tepi_new = 0.5 * (T_therm + T_surf)
            Thypo_new = 0.5 * (T_hypo + T_therm)
            
        Csse_new = Css2
        Cssh_new = Css2
    
    # iceon
    if Tepi_new <= Twinter and iceon == max(t):
        iceon = tyear

    VAR_LAKE={"T_epi":Tepi_new,"T_hypo":Thypo_new,"Css_epi":Csse_new,"Css_hypo":Cssh_new,"h_epi":hepi_new}
    return VAR_LAKE, iceon

# %%
# main code test
for k in np.arange(300): 
    VAR_LAKE={"T_epi":T_epi[k],"T_hypo":T_hypo[k],"Css_epi":Css_epi[k],"Css_hypo":Css_hypo[k],"h_epi":h_epi[k]}
    
    if k < iceoff or k > iceon:
        VAR_LAKE = case1(VAR_LAKE)
        
    elif h_epi[k] >= hmax - 0.11:
        VAR_LAKE, iceon = case2(VAR_LAKE)
        
    else:
        VAR_LAKE = case1(VAR_LAKE)
    lake_list = []
    lake_list.append(VAR_LAKE.copy())
    print(k, lake_list)
    print(iceon)
# Out:
# 0 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 1 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 2 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 3 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 4 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 5 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 6 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 7 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 8 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 9 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 10 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 11 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 12 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 13 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 14 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 15 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 16 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 17 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 18 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 19 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 20 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 21 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 22 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 23 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 24 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 25 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 26 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 27 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 28 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 29 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 30 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 31 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 32 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 33 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 34 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 35 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 36 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 37 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 38 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 39 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 40 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 41 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 42 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 43 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 44 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 45 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 46 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 47 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 48 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 49 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 50 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 51 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 52 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 53 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 54 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 55 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 56 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 57 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 58 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 59 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 60 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 61 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 62 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 63 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 64 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 65 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 66 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 67 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 68 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 69 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 70 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 71 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 72 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 73 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 74 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 75 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 76 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 77 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 78 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 79 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 80 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 81 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 82 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 83 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 84 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 85 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 86 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 87 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 88 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 89 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 90 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 91 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 92 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 93 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 94 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 95 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 96 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 97 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 98 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 99 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 100 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 101 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 102 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 103 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 104 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 105 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 106 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 107 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 108 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 109 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 110 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 111 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 112 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 113 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 114 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 115 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 116 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 117 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 118 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 119 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 120 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 121 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 122 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 123 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 124 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 125 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 126 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 127 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 128 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 129 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 130 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 131 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 132 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 133 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 134 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 135 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 136 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 137 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 138 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 139 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 140 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 141 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 142 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 143 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 144 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 145 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 146 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 147 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 148 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 149 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 150 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 151 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 152 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 153 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 154 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 155 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 156 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 157 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 158 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 159 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 160 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 161 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 162 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 163 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 164 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 165 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 166 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 167 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 168 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 169 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 170 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 171 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 172 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 173 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 174 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 175 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 176 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 177 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 178 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 179 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 180 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 181 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 182 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 183 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 184 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 185 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 186 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 187 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 188 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 189 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 190 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 191 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 192 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 193 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 194 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 195 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 196 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 197 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 198 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 199 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 200 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 201 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 202 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 203 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 204 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 205 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 206 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 207 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 208 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 209 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 210 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 211 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 212 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 213 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 214 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 215 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 216 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 217 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 218 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 219 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 220 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 221 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 222 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 223 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 224 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 225 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 226 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 227 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 228 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 229 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 230 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 231 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 232 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 233 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 234 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 235 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 236 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 237 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 238 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 239 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 240 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 241 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 242 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 243 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 244 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 245 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 246 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 247 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 248 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 249 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 250 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 251 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 252 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 253 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 254 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 255 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 256 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 257 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 258 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 259 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 260 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 261 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 262 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 263 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 264 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 265 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 266 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 267 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 268 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 269 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 270 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 271 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 272 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 273 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 274 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 275 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 276 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 277 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 278 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 279 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 280 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 281 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 282 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 283 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 284 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 285 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 286 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 287 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 288 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 289 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 290 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 291 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 292 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 293 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 294 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 295 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 296 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 297 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 298 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
# 299 [{'T_epi': 4, 'T_hypo': 4, 'Css_epi': 100, 'Css_hypo': 100, 'h_epi': 8}]
# 730
